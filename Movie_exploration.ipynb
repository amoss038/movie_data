# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %matplotlib inline
plt.style.use('ggplot')

# %%
movie = pd.read_csv("tmdb_5000_movies.csv")

# %%
movie.head(10)
movie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movie.describe
# Out:
# <bound method NDFrame.describe of          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# ...

# %%
movies_new = movie[["budget", 'original_title','popularity', 'release_date','revenue', 'runtime', 'vote_average',
       'vote_count']]

# %%
movies_new.head(10)
# Out:
#       budget                            original_title  popularity  \
# 0  237000000                                    Avatar  150.437577
# 1  300000000  Pirates of the Caribbean: At World's End  139.082615
# 2  245000000                                   Spectre  107.376788
# 3  250000000                     The Dark Knight Rises  112.312950
# 4  260000000                               John Carter   43.926995
# 5  258000000                              Spider-Man 3  115.699814
# 6  260000000                                   Tangled   48.681969
# 7  280000000                   Avengers: Age of Ultron  134.279229
# 8  250000000    Harry Potter and the Half-Blood Prince   98.885637
# 9  250000000        Batman v Superman: Dawn of Justice  155.790452
#
#   release_date     revenue  runtime  vote_average  vote_count
# 0   2009-12-10  2787965087    162.0           7.2       11800
# 1   2007-05-19   961000000    169.0           6.9        4500
# ...

# %%
movies_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   budget          4803 non-null   int64
#  1   original_title  4803 non-null   object
#  2   popularity      4803 non-null   float64
#  3   release_date    4802 non-null   object
#  4   revenue         4803 non-null   int64
#  5   runtime         4801 non-null   float64
#  6   vote_average    4803 non-null   float64
#  7   vote_count      4803 non-null   int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 300.3+ KB

# %%
budget_g = movies_new.groupby('revenue')
budget_g.head()
# Out:
#          budget                            original_title  popularity  \
# 0     237000000                                    Avatar  150.437577
# 1     300000000  Pirates of the Caribbean: At World's End  139.082615
# 2     245000000                                   Spectre  107.376788
# 3     250000000                     The Dark Knight Rises  112.312950
# 4     260000000                               John Carter   43.926995
# ...         ...                                       ...         ...
# 4775          0                               Funny Ha Ha    0.362633
# 4788      12000                            Pink Flamingos    4.553644
# 4792      20000                                       キュア    0.212443
# 4796       7000                                    Primer   23.307949
# 4798     220000                               El Mariachi   14.269792
#
#      release_date     revenue  runtime  vote_average  vote_count
# ...

# %%
plt.plot('budget', 'revenue')
plt.title("look at me")
plt.xlabel('rev')
plt.ylabel('budg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-36be0181a3ca> in <module>
# ----> 1 plt.plot('budget', 'revenue')
#       2 plt.title("look at me")
#       3 plt.xlabel('rev')
#       4 plt.ylabel('budg')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...
